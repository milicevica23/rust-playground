# %%
import polars as pl

q = (
    pl.scan_csv("./data/archive/csv/player.csv")
    .filter(pl.col("full_name") == "Nikola Jokic")
)

df = q.collect()
df
#id 203999
# Out:
# shape: (1, 5)
# ┌────────┬──────────────┬────────────┬───────────┬───────────┐
# │ id     ┆ full_name    ┆ first_name ┆ last_name ┆ is_active │
# │ ---    ┆ ---          ┆ ---        ┆ ---       ┆ ---       │
# │ i64    ┆ str          ┆ str        ┆ str       ┆ i64       │
# ╞════════╪══════════════╪════════════╪═══════════╪═══════════╡
# │ 203999 ┆ Nikola Jokic ┆ Nikola     ┆ Jokic     ┆ 1         │
# └────────┴──────────────┴────────────┴───────────┴───────────┘

# %%
# Out:
# shape: (4831, 5)
# ┌─────────┬─────────────────────┬────────────┬──────────────┬───────────┐
# │ id      ┆ full_name           ┆ first_name ┆ last_name    ┆ is_active │
# │ ---     ┆ ---                 ┆ ---        ┆ ---          ┆ ---       │
# │ i64     ┆ str                 ┆ str        ┆ str          ┆ i64       │
# ╞═════════╪═════════════════════╪════════════╪══════════════╪═══════════╡
# │ 76001   ┆ Alaa Abdelnaby      ┆ Alaa       ┆ Abdelnaby    ┆ 0         │
# │ 76002   ┆ Zaid Abdul-Aziz     ┆ Zaid       ┆ Abdul-Aziz   ┆ 0         │
# │ 76003   ┆ Kareem Abdul-Jabbar ┆ Kareem     ┆ Abdul-Jabbar ┆ 0         │
# │ 51      ┆ Mahmoud Abdul-Rauf  ┆ Mahmoud    ┆ Abdul-Rauf   ┆ 0         │
# │ ...     ┆ ...                 ┆ ...        ┆ ...          ┆ ...       │
# │ 78647   ┆ Jim Zoet            ┆ Jim        ┆ Zoet         ┆ 0         │
# │ 78648   ┆ Bill Zopf           ┆ Bill       ┆ Zopf         ┆ 0         │
# ...
